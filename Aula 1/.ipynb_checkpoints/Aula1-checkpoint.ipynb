# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1             #tempo/delay

#Entrar no sistema
pyautogui.hotkey("ctrl", "t")   #abrindo uma aba
pyperclip.copy  ("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing") #copiando link
pyautogui.hotkey("ctrl", "v")   #colando link
pyautogui.press ("enter")       #entrando no link

#Carregar Sistema
time.sleep(5)                   #carregar sistema (demorar 5 sesgundos)

#Navegar no sistema
pyautogui.click(x=419, y=313, clicks=2 ) # Passo 2: Navegar até o local do relatório (entrar na pasta Exportar)
time.sleep(2)
#Fazer o download 
pyautogui.click(x=419, y=313)  #Clicar exportar
pyautogui.click(x=1150, y=205) #Clicar nos 3 pontinhos
pyautogui.click(x=855, y=598)  #Clicar no download

time.sleep(5)                  #esperar download

# %%
#Importar a base de vendas para o Python
#pandas
#numpy
#openpyxl

import pandas as pd


tabela = pd.read_excel(r"C:\Users\marco\Documents\Projetos\Pyton\ProjetosHashTag\Aula 1\Exportar\Vendas - Dez.xlsx")
display(tabela)

#Calcular o faturamento e qtd de produtos vendido(os indicadores)
faturamento   = tabela["Valor Final"].sum()
qtde_produtos = tabela ["Quantidade"].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#Entrar no navegador
pyautogui.hotkey("win")
time.sleep(2)
pyperclip.copy("Google Chrome")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("enter")  
time.sleep(2)

#Enviar email para diretoria
#pyautogui.hotkey("ctrl", "t")   #abrindo uma aba, quando navegador ja estiver aberto.

pyperclip.copy  ("https://mail.google.com/mail/u/0/?hl=pt_BR#inbox") #copiando link
pyautogui.hotkey("ctrl", "v")   #colando link
pyautogui.press ("enter")       #entrando no link

time.sleep(2)

#Entrar no Gmail
pyautogui.click(x=99, y=231)   #Click no botão escrever
time.sleep(3)

#destino
pyperclip.copy  ("marcosf.ferr@gmail.com") #Inserir email
pyautogui.hotkey("ctrl", "v")

#mudar p/ campo assunto
pyautogui.press ("tab") 

time.sleep(2)
pyperclip.copy("Relatório de Vendas") #preencher campo assunto
pyautogui.hotkey("ctrl", "v")

#mudar p/ campo do corpo de email   
pyautogui.press("tab")

#Escrever o email
texto = f""" Minha primeira aula de automação com Python

Faturamento R$: {faturamento:,.2f}
Quantidade de Produtos: {qtde_produtos:,}

MFF
"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")
time.sleep(2)

#Enviar
pyautogui.hotkey("ctrl", "Enter")
